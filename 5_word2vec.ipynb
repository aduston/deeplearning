# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5241, 3082, 12, 6, 195, 2, 3135, 46, 59, 156]

# %%
" ".join(reverse_dictionary[d] for d in data[:10])
# Out:
# 'anarchism originated as a term of abuse first used against'

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'of', 'term', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.180771
# Nearest to a: westport, incorporating, merchant, otranto, woodlands, martyr, besiege, replication,
# Nearest to so: yamamoto, ballista, outer, alleviate, counting, geneticists, babylonian, acquiring,
# Nearest to see: epigrams, volleyball, regretted, abu, mais, tale, projectile, fringed,
# Nearest to would: npc, additions, anders, athens, judy, schumann, istrian, industrialized,
# Nearest to eight: imitations, zimbabwean, secombe, duvall, partnering, dienes, operationally, jacinto,
# Nearest to there: saeed, reasoner, coughlin, stabilised, shank, lemmings, psychedelic, hosting,
# Nearest to are: crucifixion, uhf, pinky, glyphs, poke, lawfully, entrants, dating,
# Nearest to years: adequately, byzantium, rohe, kenny, reactivity, ruhr, daily, educators,
# Nearest to which: evocative, unit, flower, trafalgar, calculated, shareholder, empiricists, mango,
# Nearest to who: eac, lutenist, ire, reissue, comforts, rgen, autistics, articulate,
# Nearest to after: agassiz, low, enthusiast, texaco, engineers, dash, homophobic, enshrined,
# Nearest to is: disavowed, debut, confessors, apparitions, remonstrance, lindo, recording, xun,
# Nearest to six: exam, castilla, attenuation, preterist, less, tilsit, jose, myriad,
# Nearest to about: calamine, mannered, coalescence, exhausted, hohlbein, disregard, liars, adamant,
# Nearest to that: world, lle, sheehan, beja, clues, kinds, tanenbaum, industrial,
# Nearest to other: arne, guin, perpendicularly, increases, simplicity, ceres, ayyash, grease,
# Average loss at step 2000: 4.364607
# Average loss at step 4000: 3.865611
# Average loss at step 6000: 3.792372
# Average loss at step 8000: 3.690523
# Average loss at step 10000: 3.616987
# Nearest to a: the, this, plenary, cpk, backbones, analogues, jersey, his,
# Nearest to so: still, later, ballista, zambian, grew, eschew, acquiring, petite,
# Nearest to see: epigrams, aerobic, cushitic, johannine, mais, engelbert, zapotec, volleyball,
# Nearest to would: can, may, will, istrian, confessions, additions, investigation, could,
# Nearest to eight: nine, six, seven, five, three, four, zero, two,
# Nearest to there: it, rpgs, hosting, who, they, phosphorylation, also, shank,
# Nearest to are: were, is, have, financially, knopf, cancelled, trochaic, jornal,
# Nearest to years: adequately, interlude, huggins, rohe, east, warners, planar, pruning,
# Nearest to which: this, that, it, often, who, broadest, tt, wallet,
# Nearest to who: also, eac, he, ire, comforts, lite, which, there,
# Nearest to after: low, agassiz, effects, for, collagen, enthusiast, in, lds,
# Nearest to is: was, are, has, be, anthropogenic, freiburg, were, telescopes,
# Nearest to six: seven, five, eight, nine, four, three, zero, two,
# Nearest to about: exhausted, bargaining, boys, calamine, ciphers, liars, logics, leaning,
# Nearest to that: which, shasta, plunging, could, who, because, seam, it,
# Nearest to other: callahan, industry, guin, confers, constitutive, prescient, byzantines, barometer,
# Average loss at step 12000: 3.604198
# Average loss at step 14000: 3.571518
# Average loss at step 16000: 3.416656
# Average loss at step 18000: 3.454663
# Average loss at step 20000: 3.542201
# Nearest to a: the, any, enlists, this, gemara, selling, integrates, phnom,
# Nearest to so: later, too, ballista, roar, diaspora, emma, guanine, acquiring,
# Nearest to see: epigrams, aerobic, johannine, cushitic, laurier, zapotec, citadels, mais,
# Nearest to would: can, will, may, could, should, must, might, nubian,
# Nearest to eight: six, nine, seven, five, four, three, two, zero,
# Nearest to there: it, they, he, who, rpgs, which, that, dfts,
# Nearest to are: were, is, have, other, tunis, hanks, donaghy, connecting,
# Nearest to years: adequately, huggins, warners, interlude, days, pruning, dysfunction, planar,
# Nearest to which: that, who, this, it, but, also, what, wallet,
# Nearest to who: which, he, also, often, there, they, eac, opener,
# Nearest to after: before, during, effects, low, lds, for, while, agassiz,
# Nearest to is: was, has, are, were, be, geostationary, vineyards, but,
# Nearest to six: eight, five, seven, four, nine, three, two, zero,
# Nearest to about: exhausted, angiotensin, pile, quench, haines, wesley, belarus, boys,
# Nearest to that: which, but, however, because, this, what, there, seam,
# Nearest to other: many, callahan, some, these, are, constitutive, hgp, reservation,
# Average loss at step 22000: 3.500178
# Average loss at step 24000: 3.490198
# Average loss at step 26000: 3.484365
# Average loss at step 28000: 3.482293
# Average loss at step 30000: 3.504121
# Nearest to a: the, any, integrates, polyphyletic, cpk, enlists, globally, analogues,
# Nearest to so: later, too, bruun, roar, sporadic, gehenna, backwards, zambian,
# Nearest to see: epigrams, laurier, johannine, aerobic, cushitic, nsg, mais, diversity,
# Nearest to would: can, will, may, could, should, must, might, cannot,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to there: they, it, he, believed, rpgs, who, clive, benefitting,
# Nearest to are: were, have, is, including, include, while, do, tunis,
# Nearest to years: adequately, days, warners, interlude, dysfunction, huggins, prerogatives, months,
# Nearest to which: that, this, but, who, it, also, these, what,
# Nearest to who: he, which, also, they, septimania, often, lavin, eac,
# Nearest to after: before, during, at, when, while, lds, eridu, dist,
# Nearest to is: was, has, are, be, were, ethnicity, seri, coalition,
# Nearest to six: eight, four, nine, five, seven, three, zero, two,
# Nearest to about: pile, exhausted, skimmed, bruxelles, ciphers, pinnacle, duplicates, healey,
# Nearest to that: which, this, what, but, because, however, finally, seam,
# Nearest to other: different, hgp, callahan, various, some, organic, industry, bitrates,
# Average loss at step 32000: 3.505060
# Average loss at step 34000: 3.495509
# Average loss at step 36000: 3.456346
# Average loss at step 38000: 3.304251
# Average loss at step 40000: 3.430445
# Nearest to a: the, another, any, incurable, precarious, nieve, analogues, exponentially,
# Nearest to so: later, too, sporadic, backwards, bruun, retroactively, stray, more,
# Nearest to see: epigrams, laurier, duryodhana, but, aerobic, rhotic, nsg, theorized,
# Nearest to would: will, can, could, may, should, must, might, cannot,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to there: it, they, he, which, currently, often, now, benefitting,
# Nearest to are: were, have, is, include, including, these, be, hanks,
# Nearest to years: days, adequately, months, year, warners, huggins, quicklime, prerogatives,
# Nearest to which: that, this, also, who, it, what, there, often,
# Nearest to who: which, he, often, also, lavin, opener, they, septimania,
# Nearest to after: before, during, when, while, from, through, waitress, since,
# Nearest to is: was, are, be, has, floating, ethnicity, heron, misogynist,
# Nearest to six: five, eight, seven, four, three, nine, two, zero,
# Nearest to about: pile, skimmed, duplicates, codebreakers, on, surpluses, hauge, simd,
# Nearest to that: which, this, what, however, transcendent, it, who, but,
# Nearest to other: callahan, various, hgp, different, analyzing, organic, these, prescient,
# Average loss at step 42000: 3.439068
# Average loss at step 44000: 3.452766
# Average loss at step 46000: 3.451276
# Average loss at step 48000: 3.351141
# Average loss at step 50000: 3.382509
# Nearest to a: another, the, any, integrates, classified, afraid, cpk, ozarks,
# Nearest to so: too, kites, backwards, ikea, bruun, recompense, sporadic, panels,
# Nearest to see: duryodhana, cigars, nsg, include, epigrams, list, laurier, rhotic,
# Nearest to would: could, will, can, may, should, must, might, cannot,
# Nearest to eight: six, seven, nine, four, five, three, zero, two,
# Nearest to there: they, it, he, now, often, believed, still, who,
# Nearest to are: were, is, have, include, these, be, those, appear,
# Nearest to years: days, adequately, months, year, times, hours, ways, quicklime,
# Nearest to which: that, this, also, who, often, what, but, these,
# Nearest to who: he, which, often, she, they, also, there, already,
# Nearest to after: before, during, when, while, through, though, since, lds,
# Nearest to is: was, are, has, holds, became, ethnicity, becomes, be,
# Nearest to six: eight, seven, four, three, nine, five, two, zero,
# Nearest to about: pile, codebreakers, attesting, simd, skimmed, equating, hauge, edifice,
# Nearest to that: which, however, what, seam, who, this, aliases, because,
# Nearest to other: various, different, analyzing, callahan, organic, increases, reservation, these,
# Average loss at step 52000: 3.436392
# Average loss at step 54000: 3.425634
# Average loss at step 56000: 3.441743
# Average loss at step 58000: 3.395579
# Average loss at step 60000: 3.395973
# Nearest to a: the, another, any, enough, integrates, cpk, cheers, incurable,
# Nearest to so: too, backwards, ikea, sporadic, schemas, kites, stated, bruun,
# Nearest to see: but, include, nsg, includes, duryodhana, cigars, list, and,
# Nearest to would: could, will, may, can, should, must, might, cannot,
# Nearest to eight: six, nine, seven, five, four, three, zero, one,
# Nearest to there: they, it, now, he, still, this, midas, often,
# Nearest to are: were, is, have, include, including, be, these, those,
# Nearest to years: days, months, adequately, year, times, quicklime, minutes, hours,
# Nearest to which: that, this, what, it, who, also, however, aliases,
# Nearest to who: he, which, she, lavin, never, that, still, often,
# Nearest to after: before, during, when, while, lds, through, sprouted, explain,
# Nearest to is: was, are, has, be, although, remains, does, jasmine,
# Nearest to six: eight, five, four, seven, nine, three, two, zero,
# Nearest to about: pile, skimmed, codebreakers, equating, edifice, sachet, attesting, arouse,
# Nearest to that: which, what, however, this, it, there, aliases, who,
# Nearest to other: various, different, increases, analyzing, several, more, organic, many,
# Average loss at step 62000: 3.246023
# Average loss at step 64000: 3.258535
# Average loss at step 66000: 3.402268
# Average loss at step 68000: 3.394586
# Average loss at step 70000: 3.358089
# Nearest to a: another, the, any, integrates, enlists, chattel, enough, every,
# Nearest to so: too, backwards, sporadic, schemas, ikea, later, kites, thus,
# Nearest to see: include, but, duryodhana, list, nsg, and, cigars, phrasing,
# Nearest to would: will, could, can, may, might, should, must, cannot,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to there: they, it, still, we, now, he, often, she,
# Nearest to are: were, is, have, including, include, these, be, although,
# Nearest to years: days, months, year, adequately, decades, hours, minutes, times,
# Nearest to which: that, this, also, what, but, often, usually, these,
# Nearest to who: lavin, she, which, he, never, still, opener, stanza,
# Nearest to after: before, during, while, when, lds, from, until, through,
# Nearest to is: was, has, are, be, although, seems, does, holds,
# Nearest to six: four, eight, seven, five, nine, three, two, zero,
# Nearest to about: equating, over, edifice, skimmed, codebreakers, approximately, pile, proudly,
# Nearest to that: which, what, however, this, but, aliases, shasta, also,
# Nearest to other: various, different, analyzing, increases, blind, others, historical, staub,
# Average loss at step 72000: 3.375085
# Average loss at step 74000: 3.349560
# Average loss at step 76000: 3.319820
# Average loss at step 78000: 3.350867
# Average loss at step 80000: 3.378561
# Nearest to a: another, the, gemara, every, analogues, precarious, chattel, rhondda,
# Nearest to so: ikea, too, later, kites, backwards, schemas, sporadic, ocogs,
# Nearest to see: include, links, includes, refer, cigars, including, but, laurier,
# Nearest to would: will, could, may, can, might, must, should, cannot,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to there: it, they, he, still, abbess, she, currently, usually,
# Nearest to are: were, include, have, is, although, those, including, while,
# Nearest to years: days, months, year, minutes, adequately, decades, hours, times,
# Nearest to which: this, that, usually, also, what, based, actually, often,
# Nearest to who: he, lavin, she, often, monism, opener, they, never,
# Nearest to after: before, during, when, while, until, lds, despite, though,
# Nearest to is: was, has, becomes, are, became, although, remains, holds,
# Nearest to six: five, seven, eight, four, three, nine, two, zero,
# Nearest to about: equating, over, approximately, skimmed, edifice, attesting, sachet, archetypical,
# Nearest to that: which, however, seam, imagine, where, what, ambrosia, aliases,
# Nearest to other: various, others, different, analyzing, blind, dolphins, callahan, many,
# Average loss at step 82000: 3.411963
# Average loss at step 84000: 3.412188
# Average loss at step 86000: 3.388474
# Average loss at step 88000: 3.353377
# Average loss at step 90000: 3.362217
# Nearest to a: the, every, another, any, integrates, afraid, electrochemical, chattel,
# Nearest to so: too, backwards, if, kites, ikea, later, gabrielle, plenary,
# Nearest to see: list, cigars, links, duryodhana, include, phrasing, external, references,
# Nearest to would: will, could, should, might, can, may, must, cannot,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Nearest to there: they, it, he, still, we, she, abbess, therefore,
# Nearest to are: were, is, include, have, these, those, although, including,
# Nearest to years: days, months, year, decades, hours, minutes, adequately, ways,
# Nearest to which: that, this, also, what, usually, actually, but, these,
# Nearest to who: he, often, opener, already, she, lavin, which, tasso,
# Nearest to after: before, during, when, while, until, despite, upon, under,
# Nearest to is: was, has, are, be, although, becomes, spray, became,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to about: equating, over, skimmed, pile, approximately, edifice, attesting, question,
# Nearest to that: which, however, what, but, lister, terse, because, aliases,
# Nearest to other: various, multiple, others, analyzing, blind, different, maser, authoritarian,
# Average loss at step 92000: 3.404148
# Average loss at step 94000: 3.252543
# Average loss at step 96000: 3.356967
# Average loss at step 98000: 3.242681
# Average loss at step 100000: 3.355449
# Nearest to a: the, any, integrates, another, precarious, chattel, enough, evaporative,
# Nearest to so: too, thus, then, backwards, ikea, schemas, kites, later,
# Nearest to see: list, includes, links, include, cigars, external, references, phrasing,
# Nearest to would: will, could, can, might, should, may, must, cannot,
# Nearest to eight: seven, nine, six, five, four, zero, three, two,
# Nearest to there: they, it, still, he, we, abbess, she, usually,
# Nearest to are: were, include, have, is, these, those, maize, be,
# Nearest to years: days, months, year, minutes, decades, hours, centuries, adequately,
# Nearest to which: that, this, usually, actually, what, but, also, xxxi,
# Nearest to who: he, often, she, which, lavin, still, monism, opener,
# Nearest to after: before, during, when, while, until, without, despite, upon,
# Nearest to is: was, has, be, becomes, although, became, are, seems,
# Nearest to six: four, seven, five, eight, nine, three, two, zero,
# Nearest to about: equating, pile, skimmed, upscale, over, approximately, attesting, edifice,
# Nearest to that: which, what, however, because, when, lister, where, aliases,
# Nearest to other: various, others, blind, multiple, bitrates, analyzing, individual, several,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_cbow_batch(batch_size, skip_window, data=data):
    global data_index
    batch = np.ndarray(shape=(batch_size, skip_window * 2), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    for i in range(batch_size):
        batch_data_index = data_index
        for j in range(skip_window):
            batch[i, j] = data[batch_data_index]
            batch_data_index += 1
        labels[i, 0] = data[batch_data_index]
        batch_data_index += 1
        for j in range(skip_window):
            batch[i, skip_window + j] = data[batch_data_index]
            batch_data_index += 1
        data_index = (data_index + 1) % (len(data) - span + 1)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:7]])

data_index = 0
batch, labels = generate_cbow_batch(batch_size=4, skip_window=2, data=data[:7])
for bi in range(4):
    print("label: " + reverse_dictionary[labels[bi][0]])
    print("context: " + " ".join([reverse_dictionary[b] for b in batch[bi]]))
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse']
# label: as
# context: anarchism originated a term
# label: a
# context: originated as term of
# label: term
# context: as a of abuse
# label: as
# context: anarchism originated a term

# %%
data_index = 0
batch, labels = generate_cbow_batch(batch_size=3, skip_window=1, data=data[:4])
for bi in range(3):
    print("label: " + reverse_dictionary[labels[bi][0]])
    print("context: " + " ".join([reverse_dictionary[b] for b in batch[bi]]))
# Out:
# label: originated
# context: anarchism as
# label: as
# context: originated a
# label: originated
# context: anarchism as

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, skip_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    averaged_embed = tf.reduce_mean(embed, axis=1)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=averaged_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
data_index = 0
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_cbow_batch(batch_size, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.631472
# Nearest to UNK: hyde, cnet, adiabats, polymer, infecting, croats, serpent, pavilion,
# Nearest to as: plastic, yassin, supported, ambient, frontiers, soured, refounded, del,
# Nearest to i: motet, astrologically, vries, floor, greenspan, italian, cottages, abatement,
# Nearest to all: adventist, connect, catalyzed, deterioration, ath, concerning, paideia, mjf,
# Nearest to were: unconsciousness, majapahit, ams, wirth, hatton, approbation, heraclitus, daffodils,
# Nearest to five: undergraduate, vms, libels, unchanged, bloomfield, recherche, spatially, freely,
# Nearest to american: tripoli, junkie, pentastar, exhortation, perseverance, safari, side, encrypted,
# Nearest to called: azathoth, angles, richelieu, vagina, tamers, oxidise, catal, append,
# Nearest to between: warez, cartier, agrippina, janssen, levite, vytautas, meditation, aha,
# Nearest to have: ulema, infantry, inexpensive, nora, legislatures, corporatist, missal, gradients,
# Nearest to some: piecemeal, canonic, bolts, savoy, beno, separable, whitepapers, tedious,
# Nearest to state: troubled, buteo, closing, kenilworth, hammerheads, shank, ultrasound, pegs,
# Nearest to s: asgard, dynastic, commandant, recreation, film, cookbook, jute, excrement,
# Nearest to an: beth, synods, memorization, slippage, accomplishments, impressed, ucl, deconvolution,
# Nearest to to: pathfinder, sx, diner, mixing, coventry, sus, caleb, bulb,
# Nearest to states: vehement, predates, bund, probate, ibook, hand, gpl, intellivision,
# Average loss at step 2000: 4.042142
# Average loss at step 4000: 3.520769
# Average loss at step 6000: 3.327776
# Average loss at step 8000: 3.218535
# Average loss at step 10000: 3.141392
# Nearest to UNK: albanian, deluded, aggrieved, advised, mandatory, pinky, embarked, getty,
# Nearest to as: when, frontiers, equator, corse, into, del, micronations, became,
# Nearest to i: decry, abolitionists, lifeson, astrologically, marais, intransitive, marketable, jit,
# Nearest to all: adventist, photosynthesis, things, viable, eero, romances, connect, reviewed,
# Nearest to were: are, was, religious, warps, juggling, have, educational, is,
# Nearest to five: eight, six, three, nine, seven, zero, four, two,
# Nearest to american: british, mudslides, oldcastle, structuralist, annie, jolly, tlc, safari,
# Nearest to called: azathoth, ashikaga, balderus, vagina, grissom, richelieu, helped, nerd,
# Nearest to between: cartier, main, in, agrippina, has, mahathir, optimum, lice,
# Nearest to have: had, has, be, taoist, are, lc, matrilineal, nora,
# Nearest to some: many, cayley, canonic, standard, election, various, separable, relaxing,
# Nearest to state: fathom, blocked, horn, busting, pegs, corporatism, kenilworth, heap,
# Nearest to s: dynastic, khosrau, enrollments, plesiosaur, asgard, sparking, regained, jennings,
# Nearest to an: slippage, sms, reactions, beth, gout, mencius, hampton, mentors,
# Nearest to to: can, coventry, pathfinder, hamel, bulb, will, petals, publ,
# Nearest to states: hand, vehement, predates, nations, egyptology, hamsters, philby, bund,
# Average loss at step 12000: 3.153293
# Average loss at step 14000: 3.141650
# Average loss at step 16000: 3.123142
# Average loss at step 18000: 3.111330
# Average loss at step 20000: 2.990031
# Nearest to UNK: n, et, l, gandhi, exaggerated, word, besiege, deluded,
# Nearest to as: when, corse, equator, communication, became, grille, micronations, frontiers,
# Nearest to i: we, you, marais, he, synthesizer, carr, iguana, abolitionists,
# Nearest to all: things, photosynthesis, adventist, reviewed, flaps, eero, miscarriage, out,
# Nearest to were: are, have, was, had, resounding, be, aia, acronym,
# Nearest to five: seven, six, three, four, eight, zero, nine, two,
# Nearest to american: british, jolly, oldcastle, palestinian, structuralist, mudslides, variants, sacramento,
# Nearest to called: azathoth, folktales, grissom, balderus, striker, firefighting, ordinals, xinhua,
# Nearest to between: main, cartier, in, with, agrippina, symbiotic, mahathir, goal,
# Nearest to have: had, has, were, are, taoist, be, ushering, kensington,
# Nearest to some: many, these, various, several, canonic, wrestling, cayley, dip,
# Nearest to state: fathom, ral, blocked, horn, absence, anarcho, heap, corporatism,
# Nearest to s: dynastic, sparking, khosrau, whose, actuality, jennings, asgard, jeffrey,
# Nearest to an: beth, sms, slippage, romanians, chaplin, impressed, dana, reactions,
# Nearest to to: will, could, would, petals, entanglement, sx, bulb, pathfinder,
# Nearest to states: nations, retaliation, narita, hand, marius, vehement, predates, monsters,
# Average loss at step 22000: 3.057549
# Average loss at step 24000: 3.051276
# Average loss at step 26000: 2.966108
# Average loss at step 28000: 3.007984
# Average loss at step 30000: 2.982019
# Nearest to UNK: exaggerated, jiang, motorized, lasor, l, word, scout, von,
# Nearest to as: when, too, culminate, corse, after, hobsbawm, usurpers, dieu,
# Nearest to i: you, we, synthesizer, carr, he, marais, iguana, astrologically,
# Nearest to all: eero, things, photosynthesis, reviewed, flaps, some, miscarriage, viridis,
# Nearest to were: are, have, was, had, remain, be, been, aia,
# Nearest to five: four, six, seven, three, eight, zero, nine, two,
# Nearest to american: british, jolly, mudslides, palestinian, variants, oldcastle, german, structuralist,
# Nearest to called: azathoth, ordinals, folktales, positrons, firefighting, closest, xinhua, patriarchy,
# Nearest to between: with, in, main, cartier, symbiotic, agrippina, mahathir, rufus,
# Nearest to have: had, has, were, are, taoist, be, never, ushering,
# Nearest to some: many, several, these, various, those, wrestling, canonic, any,
# Nearest to state: fathom, lubrication, ral, heap, horn, absence, blocked, ear,
# Nearest to s: dynastic, whose, asgard, khosrau, my, jennings, millay, sparking,
# Nearest to an: chaplin, beth, romanians, slippage, dana, finalized, sms, gout,
# Nearest to to: will, must, would, could, can, entanglement, towards, petals,
# Nearest to states: nations, kingdom, monsters, marius, narita, egyptology, predates, retaliation,
# Average loss at step 32000: 2.973832
# Average loss at step 34000: 2.812586
# Average loss at step 36000: 2.938032
# Average loss at step 38000: 2.935193
# Average loss at step 40000: 2.919279
# Nearest to UNK: gandhi, van, pfeiffer, von, rsha, mulligan, henotheism, die,
# Nearest to as: when, mateo, culminate, too, dieu, grille, corse, inn,
# Nearest to i: you, we, synthesizer, carr, psc, iguana, plenary, marais,
# Nearest to all: eero, various, some, both, things, viridis, many, photosynthesis,
# Nearest to were: are, have, was, had, remain, including, be, been,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to american: british, palestinian, french, variants, european, mudslides, oldcastle, german,
# Nearest to called: azathoth, positrons, ordinals, used, cartwright, closest, considered, folktales,
# Nearest to between: with, among, in, symbiotic, cartier, within, agrippina, rufus,
# Nearest to have: had, has, were, are, taoist, remain, be, ever,
# Nearest to some: many, several, various, these, any, all, those, most,
# Nearest to state: frankfurt, senate, absence, siamese, fathom, michigan, ral, heap,
# Nearest to s: asgard, dynastic, khosrau, sparking, his, beeswax, dap, jennings,
# Nearest to an: chaplin, romanians, beth, slippage, dana, gout, sms, finalized,
# Nearest to to: towards, must, would, cannot, will, entanglement, petals, through,
# Nearest to states: nations, kingdom, monsters, marius, narita, difficulties, azzam, abv,
# Average loss at step 42000: 2.917773
# Average loss at step 44000: 2.958486
# Average loss at step 46000: 2.915260
# Average loss at step 48000: 2.910144
# Average loss at step 50000: 2.841708
# Nearest to UNK: von, overflowing, smith, pfeiffer, mandatory, menial, joseph, edward,
# Nearest to as: when, too, yassin, sacking, plunging, grille, hobsbawm, corse,
# Nearest to i: we, you, plenary, carr, synthesizer, rubidium, hoaxes, ii,
# Nearest to all: eero, various, some, many, both, reviewed, out, several,
# Nearest to were: are, have, had, was, remain, be, been, including,
# Nearest to five: four, seven, eight, three, six, nine, zero, two,
# Nearest to american: british, french, german, palestinian, australian, jolly, spontaneous, brinkley,
# Nearest to called: azathoth, positrons, ordinals, used, known, folktales, considered, whitaker,
# Nearest to between: among, with, within, symbiotic, cartier, rufus, agrippina, main,
# Nearest to have: had, has, were, are, remain, require, ever, having,
# Nearest to some: many, several, various, these, any, all, certain, most,
# Nearest to state: absence, frankfurt, senate, heap, michigan, siamese, ral, dominance,
# Nearest to s: dynastic, khosrau, asgard, sparking, misdiagnosed, whose, blowout, his,
# Nearest to an: chaplin, beth, slippage, dana, romanians, finalized, sms, crystals,
# Nearest to to: must, will, towards, pathfinder, could, would, might, should,
# Nearest to states: nations, kingdom, narita, monsters, marius, difficulties, azzam, retaliation,
# Average loss at step 52000: 2.843587
# Average loss at step 54000: 2.865395
# Average loss at step 56000: 2.879434
# Average loss at step 58000: 2.739566
# Average loss at step 60000: 2.818070
# Nearest to UNK: von, van, et, der, johnson, j, pfeiffer, o,
# Nearest to as: when, plunging, too, admixture, sacking, oddly, dieu, monaco,
# Nearest to i: we, you, plenary, ii, mathbb, rubidium, g, hoaxes,
# Nearest to all: both, various, eero, some, every, many, flowered, orthographies,
# Nearest to were: are, have, was, had, remain, been, including, be,
# Nearest to five: seven, six, four, eight, three, nine, zero, two,
# Nearest to american: british, german, australian, indian, french, palestinian, english, european,
# Nearest to called: azathoth, used, considered, positrons, named, ordinals, bottlers, referred,
# Nearest to between: with, within, among, over, symbiotic, cartier, into, agrippina,
# Nearest to have: had, has, were, are, remain, require, taoist, having,
# Nearest to some: many, several, these, various, any, certain, those, most,
# Nearest to state: senate, frankfurt, michigan, heap, busting, illusions, khanates, siamese,
# Nearest to s: jeffrey, whose, khosrau, dynastic, asgard, beeswax, blowout, my,
# Nearest to an: dana, finalized, chaplin, beth, romanians, slippage, crystals, sms,
# Nearest to to: will, towards, must, would, could, might, entanglement, should,
# Nearest to states: nations, kingdom, monsters, narita, marius, difficulties, countries, azzam,
# Average loss at step 62000: 2.849904
# Average loss at step 64000: 2.828811
# Average loss at step 66000: 2.719272
# Average loss at step 68000: 2.738044
# Average loss at step 70000: 2.775167
# Nearest to UNK: et, von, pfeiffer, lasor, visceral, jour, gandhi, van,
# Nearest to as: when, thousandth, including, plunging, dieu, hatched, too, youthful,
# Nearest to i: we, you, mathbb, ii, plenary, they, iguana, prescott,
# Nearest to all: both, many, various, eero, every, reviewed, some, flowered,
# Nearest to were: are, have, had, remain, was, be, including, been,
# Nearest to five: six, eight, four, seven, three, nine, zero, two,
# Nearest to american: british, french, australian, german, italian, indian, avon, itching,
# Nearest to called: azathoth, named, used, considered, positrons, known, ordinals, referred,
# Nearest to between: within, with, among, over, into, main, from, cartier,
# Nearest to have: had, has, are, were, taoist, include, having, require,
# Nearest to some: many, several, various, these, certain, any, most, those,
# Nearest to state: senate, states, michigan, frankfurt, punt, busting, necromancers, khanates,
# Nearest to s: dynastic, whose, asgard, khosrau, jeffrey, tel, my, isbn,
# Nearest to an: dana, romanians, finalized, slippage, beth, chaplin, eduard, predicated,
# Nearest to to: towards, must, will, would, should, could, laplace, sx,
# Nearest to states: nations, kingdom, narita, monsters, marius, us, state, countries,
# Average loss at step 72000: 2.758429
# Average loss at step 74000: 2.786703
# Average loss at step 76000: 2.666043
# Average loss at step 78000: 2.794925
# Average loss at step 80000: 2.810693
# Nearest to UNK: von, mithraea, marc, leq, belgica, milano, ch, et,
# Nearest to as: plunging, when, thousandth, sacking, corse, hydroponic, hobsbawm, dieu,
# Nearest to i: we, you, they, ii, plenary, mathbb, strontium, he,
# Nearest to all: both, various, many, some, every, terraforming, eero, several,
# Nearest to were: are, was, have, remain, had, been, those, including,
# Nearest to five: six, eight, seven, four, three, zero, nine, two,
# Nearest to american: british, australian, german, italian, french, indian, european, palestinian,
# Nearest to called: named, azathoth, used, referred, considered, positrons, ordinals, known,
# Nearest to between: within, among, with, agrippina, rufus, over, rockin, symbiotic,
# Nearest to have: had, has, are, were, include, having, contain, require,
# Nearest to some: many, several, any, certain, various, these, most, islam,
# Nearest to state: senate, states, busting, punt, necromancers, amar, institutions, frankfurt,
# Nearest to s: whose, beeswax, my, jeffrey, dynastic, asgard, swore, misdiagnosed,
# Nearest to an: romanians, dana, beth, slippage, sms, trampoline, finalized, chaplin,
# Nearest to to: towards, will, must, should, would, cannot, repel, sx,
# Nearest to states: nations, kingdom, us, monsters, state, countries, marius, narita,
# Average loss at step 82000: 2.768382
# Average loss at step 84000: 2.677470
# Average loss at step 86000: 2.762502
# Average loss at step 88000: 2.735907
# Average loss at step 90000: 2.750238
# Nearest to UNK: von, pfeiffer, marc, visceral, lasor, lvares, rabid, clair,
# Nearest to as: plunging, dieu, including, admixture, sacking, because, thousandth, corse,
# Nearest to i: we, ii, you, they, iii, incantation, iv, mathbb,
# Nearest to all: both, various, some, many, several, every, terraforming, speeds,
# Nearest to were: are, have, those, was, had, been, remain, including,
# Nearest to five: six, four, seven, eight, three, zero, nine, two,
# Nearest to american: british, australian, italian, indian, german, french, european, palestinian,
# Nearest to called: named, used, azathoth, considered, referred, positrons, ordinals, known,
# Nearest to between: among, within, with, over, rufus, agrippina, rockin, billet,
# Nearest to have: had, has, were, are, include, having, require, contain,
# Nearest to some: many, several, various, certain, any, these, most, all,
# Nearest to state: states, senate, necromancers, government, busting, frankfurt, aedui, rule,
# Nearest to s: jeffrey, whose, asgard, khosrau, resumption, dynastic, tel, swore,
# Nearest to an: beth, romanians, dana, sms, finalized, slippage, gout, fulk,
# Nearest to to: towards, must, would, should, laplace, angli, cannot, pathfinder,
# Nearest to states: nations, kingdom, state, us, countries, monsters, narita, busman,
# Average loss at step 92000: 2.744369
# Average loss at step 94000: 2.671987
# Average loss at step 96000: 2.736155
# Average loss at step 98000: 2.700720
# Average loss at step 100000: 2.464368
# Nearest to UNK: von, van, du, marc, pfeiffer, des, blake, chemist,
# Nearest to as: inside, yankee, including, dieu, empress, greetings, when, telomerase,
# Nearest to i: we, you, ii, they, plenary, mathbb, prelog, hoaxes,
# Nearest to all: both, various, some, many, every, several, detachments, those,
# Nearest to were: are, was, have, had, remain, been, those, be,
# Nearest to five: seven, four, six, eight, three, zero, nine, two,
# Nearest to american: british, australian, german, italian, english, french, william, itching,
# Nearest to called: named, used, azathoth, positrons, referred, considered, see, ordinals,
# Nearest to between: among, within, with, rufus, symbiotic, involving, over, agrippina,
# Nearest to have: has, had, are, were, include, having, require, contain,
# Nearest to some: many, several, certain, any, various, all, those, numerous,
# Nearest to state: states, senate, busting, national, necromancers, punt, fathom, frankfurt,
# Nearest to s: whose, khosrau, jeffrey, dynastic, asgard, sparking, bitrate, freefall,
# Nearest to an: dana, beth, romanians, slippage, finalized, sms, chaplin, pietro,
# Nearest to to: towards, pathfinder, would, should, toward, must, will, laplace,
# Nearest to states: nations, kingdom, state, countries, us, narita, monsters, busman,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
